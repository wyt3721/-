# %%
x = 3
type (x)     #返回数值对象的类型
# Out:
# int

# %%
type(x) == int
# Out:
# True

# %%
isinstance (x,int)  #判断对象类型 ，类似type()
# Out:
# True

# %%
9999**99
# Out:
# 

# %%
0.3 + 0.2    #浮点数加法
# Out:
# 0.5

# %%
0.4 - 0.1
# Out:
# 0.30000000000000004

# %%
0.4 - 0.1 == 0.3  #浮点数运算结果
# Out:
# False

# %%
abs(0.4-0.1-0.3)<1e-6
# Out:
# True

# %%
x = 3
print(x**2)
# Out:
# 9

# %%
x += 6
x =[1, 2, 3]
x[1] = 5
print(x)
# Out:
# [1, 5, 3]

# %%
print(x[2])
# Out:
# 3

# %%
1_000_000
# Out:
# 1000000

# %%
1_2_3_4
# Out:
# 1234

# %%
1_2 + 3_4J
# Out:
# (12+34j)

# %%
1_2, 3_45
# Out:
# (12, 345)

# %%
x = 3 + 4j
y = 5 + 6j
x + y
# Out:
# (8+10j)

# %%
x*y
# Out:
# (-9+38j)

# %%
abs(x)
# Out:
# 5.0

# %%
x.imag
# Out:
# 4.0

# %%
x.real
# Out:
# 3.0

# %%
x.conjugate()
# Out:
# (3-4j)

# %%
x = 'hello world.'
x = "python isa great language."
x = '''tom said,"let 's go"'''
print(x)
# Out:
# tom said,"let 's go"

# %%
x = 'good '+'morning'
x
# Out:
# 'good morning'

# %%
x = 'good''morning'
x
# Out:
# 'goodmorning'

# %%
x = 'good'
x = x'morning'
# Out:
#   File "<ipython-input-25-ed7cfd1d5091>", line 2
#     x = x'morning'
#          ^
# SyntaxError: invalid syntax

# %%
type('hello world')
# Out:
# str

# %%
type(b'hello world')
# Out:
# bytes

# %%
'hello world'.encode('utf-8')
# Out:
# b'hello world'

# %%
'hello world'.encode('gbk')
# Out:
# b'hello world'

# %%
'董付国'.encode('utf-8')
# Out:
# b'\xe8\x91\xa3\xe4\xbb\x98\xe5\x9b\xbd'

# %%
'董付国'.encode('gbk')
# Out:
# b'\xb6\xad\xb8\xb6\xb9\xfa'

# %%
[1,2,3] + [4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
(1,2,3) + (4,)
# Out:
# (1, 2, 3, 4)

# %%
'abcd' + '1234'
# Out:
# 'abcd1234'

# %%
'A' + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-1634bdf84b0f> in <module>
# ----> 1 'A' + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
True + 3
# Out:
# 4

# %%
False + 3
# Out:
# 3

# %%
True * 3
# Out:
# 3

# %%
False * 3
# Out:
# 0

# %%
[1,2,3] * 3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
(1,2,3) * 3
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
'abc' * 3
# Out:
# 'abcabcabc'

# %%
1< 3 < 5
# Out:
# True

# %%
3 < 5 > 2
# Out:
# True

# %%
1 > 6 < 8
# Out:
# False

# %%
1 > 6 < math.sqrt(9)
# Out:
# False

# %%
[1,2,3]==[3,2,1]
# Out:
# False

# %%
{1,2,3}=={3,2,1}
# Out:
# True

# %%
{1,2,4} > {1,2,3}
# Out:
# False

# %%
{1,2,4}=={1,2,3}
# Out:
# False

# %%
3 > 5 and a > 3
# Out:
# False

# %%
3 > 5 or a > 3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-54276bab0710> in <module>
# ----> 1 3 > 5 or a > 3
#
# NameError: name 'a' is not defined

# %%
3 < 5 or a > 3
# Out:
# True

# %%
3 and 5
# Out:
# 5

# %%
3 and 5 > 2
# Out:
# True

# %%
3 is not 5
# Out:
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-56-f7ed505acb63>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   3 is not 5
# True

# %%
not 3
# Out:
# False

# %%
not 0
# Out:
# True

# %%
i = 3 
++i
# Out:
# 3

# %%
+(+3)
# Out:
# 3

# %%
i ++
# Out:
#   File "<ipython-input-61-11ea10474bca>", line 1
#     i ++
#         ^
# SyntaxError: invalid syntax

# %%
--i
# Out:
# 3

# %%
i--
# Out:
#   File "<ipython-input-63-d3f11d77f818>", line 1
#     i--
#        ^
# SyntaxError: invalid syntax

# %%
----(3+5)
# Out:
# 8

# %%
3--5
# Out:
# 8

# %%
3+-5
# Out:
# -2

# %%
list(range (5))
# Out:
# [0, 1, 2, 3, 4]

# %%
tuple(_)
# Out:
# (0, 1, 2, 3, 4)

# %%
dict(zip('1234','abcde'))
# Out:
# {'1': 'a', '2': 'b', '3': 'c', '4': 'd'}

# %%
set('1112234')
# Out:
# {'1', '2', '3', '4'}

# %%
_.add('5')
_
# Out:
# {'1', '2', '3', '4', '5'}

# %%
from random import randint
a = [randint(1,100) for i in range(10)]
print (max(a),min(a),sum(a))
sum(a/len(a))
# Out:
# 95 13 566
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-e564dc42b75e> in <module>
#       2 a = [randint(1,100) for i in range(10)]
#       3 print (max(a),min(a),sum(a))
# ----> 4 sum(a/len(a))
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %%
x = 3
print(x**2)
# Out:
# 9

# %%
x += 6
x = [1,2,3]
x[1] = 5
print(x)
# Out:
# [1, 5, 3]

# %%
print(x[2])
# Out:
# 3

# %%
3 < 5
# Out:
# True

# %%
3 and 5
# Out:
# 5
